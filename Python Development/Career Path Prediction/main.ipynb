# %%
import pandas as pd

# %%
data1 = pd.read_csv("dataset/data.csv")

# %%
print(data1)
# Out:
#     Logical_Thinking  Coding_Skills  Public_Speaking  Creativity  \
# 0                  9              8                3           4
# 1                  8              9                2           5
# 2                  5              3                8           9
# 3                  4              2                9           7
# 4                  9              5                6           3
# 5                 10              7                5           4
# 6                  3              1                8          10
# 7                  6              8                4           5
# 8                  8              4                7           6
# 9                  2              1                9           8
# 10                 9              9                3           3
# 11                 4              2                8           8
# 12                 7              6                5           5
# ...
